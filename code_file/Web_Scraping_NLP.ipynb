# %% [markdown]
# ***Web Scraping and NLP: Extracting and Analyzing News Articles***

# %%
#1.1 Copy the code examples to scrape the webpage in BeautifulSoup

import bs4 as bs
import urllib.request

url = 'https://www.usatoday.com/story/sponsor-story/everroot/2024/01/29/supplements-arent-just-for-humans-they-can-help-dogs-too/72326994007/?mvt=i&mvn=213ed4a2e7f944f0b8768d713940d4c7&mvp=NA-USAT-11238597&mvl=Key-tangent-tile%20AdUnit-%2F7103%2Fusatoday%2Fnative-front_tile%2F*%20%5BTangent%20Desktop%20Tile%5D&utm_campaign=d1f2d4e86d804ad28f5f2ac6f01d1537&utm_source=polar&utm_medium=cpc'

def text_extracted(url):
    try:
        scraped_textdata = urllib.request.urlopen(url)
        textdata = scraped_textdata.read()
        parsed_textdata = bs.BeautifulSoup(textdata, 'html.parser')
        paragraphs = parsed_textdata.find_all('p')
        formatted_text = " ".join(para.text for para in paragraphs)
        return formatted_text
    except Exception as e:
        return f"An error occurred: {e}"

text = text_extracted(url)
print(text)
# Out:
# Every dog deserves to feel their best, but like humans, they all have unique needs. Regular vet visits, proper diet and exercise can all help, but sometimes our canine pals need a little extra support above and beyond their normal diet. That’s where EverRoot dog supplements, powered by Purina come in: Developed by Purina’s experts in animal nutrition, EverRoot dog supplements come in multiple forms, covering a variety of key health benefit areas. This helps pet parents further personalize their dog’s supplement plan to meet their unique needs and preferences. With a focus on natural and organic ingredients and a commitment to traceable sourcing, EverRoot stands out for making sure that their dog supplements have everything your dog needs, without the things they don’t. To help dogs get the personalized nutrition they need, the brand teamed up with top athlete and health enthusiast Laila Ali to launch EverRoot’s new line of soft chew dog supplements. As a fitness expert, Ali believes in extending the same care she takes for her own health to her beloved pups, Malibu and Buddy. “I want them to be around for the long haul, so it feels good to know I’m giving my dogs the best chance to look and feel their best with tasty soft chews they love,” said Ali, who is the daughter of the late great professional boxer and humanitarian Muhammad Ali. To her credit, Ali is a four-time undefeated boxing world champion, CEO of Laila Ali Lifestyle brand and a devoted dog enthusiast. Inspired by her love for animals, she collaborated with EverRoot to introduce EverRoot Soft Chews. At home, these chews provide a way for Ali to take care of her own dogs based on their unique needs and preferences; she gives Buddy the EverRoot soft chew supplement for hip and joint support and the EverRoot multi-benefit soft chew to Malibu. However, pet owners don’t need to be sports heroes like Ali to provide world-class care to their pets. Thanks to EverRoot, meeting a dog’s unique wellness needs just got a whole lot easier. Finding the right ingredients is key With more than a century of experience, Purina and its scientists are trusted experts in animal nutrition. They understand that all dogs are different, and that’s why EverRoot Soft Chews are formulated to benefit their needs. EverRoot takes pride in helping dogs on their personal health journeys. To do just that, the brand has committed to sourcing and traceability practices. Every ingredient in EverRoot dog supplements has a purpose, a reason to be there. In creating supplements, they have searched the world for organic ingredients, such as soothing chamomile and Sri Lankan coconut, and sourced oils from wild-caught Alaskan salmon and cod from Marine Stewardship Council-certified fisheries. Using high-quality ingredients produces equally strong benefits. As one example, the chamomile EverRoot uses in their supplement can help calm nervous pups. Likewise, organic coconut and fish support a dog’s overall well-being, from joint, skin and coat health to mental alertness. They’ve also tapped into unexpected ingredients like green-lipped mussels harvested from New Zealand’s pristine waters to support heart health. Since ancient times, safflower oil has been a valued skin remedy and remains effective in supporting sensitive skin today. EverRoot has also sourced Montmorency cherries for their organic tart cherry powder to promote cognitive function and mental alertness. These are just a few examples of the carefully selected ingredients that ensure dogs get the best nutrition in a form that they’ll love. Health benefits and a taste dogs enjoy EverRoot’s dog supplements cover a wide range of health benefits and natural ingredients tailored for dogs including: Dr. Annie Valuska, who has a doctorate in animal behavior and works as a principal scientist in pet behavior and welfare at Purina, stresses the importance of understanding what dogs enjoy. Based on their knowledge of dogs and their targeted needs, EverRoot’s  ...

# %% [markdown]
# Interpretation: The above Python code extracts text from a given URL from sponsored story on USA Today about how supplements can help dogs, similar to their benefits for humans. It uses the BeautifulSoup library to parse HTML and collect text within paragraph tags. If an error occurs during the process, it returns an error message​

# %%
#1.2.1 Count all the named entities in the document

import spacy
from pprint import pprint
from collections import Counter

# Load the SpaCy model
nlp = spacy.load("en_core_web_sm")

article_text = text

# Processing the text with SpaCy
doc = nlp(article_text)

# Extract and print named entities and their labels
entities = [(entity.text, entity.label_) for entity in doc.ents]
pprint(entities)

# Count every named entity by their label
entity_counts = Counter([entity.label_ for entity in doc.ents])
print("\nCount of named entity types:")
pprint(entity_counts)
# Out:
# [('Purina', 'GPE'),
#  ('Purina', 'ORG'),
#  ('EverRoot', 'PRODUCT'),
#  ('Laila Ali', 'PERSON'),
#  ('EverRoot', 'PRODUCT'),
#  ('Ali', 'PERSON'),
#  ('Malibu', 'GPE'),
#  ('Buddy', 'ORG'),
#  ('Ali', 'PERSON'),
#  ('Muhammad Ali', 'PERSON'),
#  ('Ali', 'PERSON'),
#  ('four', 'CARDINAL'),
#  ('Laila Ali Lifestyle', 'PERSON'),
#  ('Soft Chews', 'PERSON'),
#  ('Ali', 'PERSON'),
#  ('Buddy the EverRoot', 'PRODUCT'),
#  ('EverRoot', 'PRODUCT'),
#  ('Malibu', 'GPE'),
#  ('Ali', 'PERSON'),
#  ('EverRoot', 'PRODUCT'),
#  ('more than a century', 'DATE'),
#  ('Purina', 'GPE'),
#  ('Soft Chews', 'PERSON'),
#  ('EverRoot', 'PRODUCT'),
#  ('Sri Lankan', 'PERSON'),
#  ('Alaskan', 'NORP'),
#  ('Marine Stewardship Council', 'ORG'),
#  ('one', 'CARDINAL'),
#  ('EverRoot', 'PRODUCT'),
#  ('New Zealand’s', 'GPE'),
#  ('today', 'DATE'),
#  ('EverRoot', 'PRODUCT'),
#  ('Annie Valuska', 'PERSON'),
#  ('Purina', 'GPE'),
#  ('EverRoot', 'PRODUCT'),
#  ('meaty treats', 'PERSON'),
#  ('Valuska', 'ORG'),
#  ('EverRoot', 'PRODUCT'),
#  ('Soft Chews', 'PERSON'),
#  ('EverRoot', 'PRODUCT')]
#
# Count of named entity types:
# Counter({'PERSON': 14,
#          'PRODUCT': 11,
#          'GPE': 6,
#          'ORG': 4,
#          'CARDINAL': 2,
#          'DATE': 2,
#          'NORP': 1})

# %% [markdown]
# Interpretation: Now, the above code analyzes a text document using the SpaCy library to identify and count named entities, such as people, organizations, products, and more. It processes the text, extracts named entities (like 'Purina', 'EverRoot', 'Laila Ali'), and counts them by type, revealing insights into the document's content. For instance, it found entities related to brands, individuals, and locations, indicating the text discusses specific products, notable people, and geographical areas.

# %%
#1.2.2 Count the most frequent tokens for the entire document

# Count the most frequent tokens in the document
tokens = [token.text.lower() for token in doc if not token.is_stop and not token.is_punct and token.is_alpha]
most_common_tokens = Counter(tokens).most_common(6)

print("\nMost frequent tokens in the document:")
pprint(most_common_tokens)
# Out:
# Most frequent tokens in the document:
# [('everroot', 19),
#  ('dog', 15),
#  ('dogs', 10),
#  ('soft', 10),
#  ('supplements', 9),
#  ('health', 8)]

# %% [markdown]
# Interpretations:This code snippet helps us count the most frequent meaningful words in a document, excluding stopwords (commonly used words of little value) and punctuation. It reveals that words like "everroot," "dog," "dogs," "soft," "supplements," and "health" are among the most mentioned, suggesting the document heavily focuses on dog health and supplements, particularly highlighting the brand "Everroot" and its products.

# %%
#1.2.3 Pick a random integer K using Python random module, then pick three consecutive sentences starting with Kth, and print these sentences. Note that you must make sure all picked sentences are in the document.

import spacy
import random

nlp = spacy.load("en_core_web_sm")
doc = nlp(article_text)  # Ensure 'article_text' contains your text

# Converting document into a list of sentences
sentences = list(doc.sents)

# Pick a random integer K
k = random.randint(0, len(sentences) - 3)

# Select three consecutive sentences starting from the Kth sentence
selected_sentences = sentences[k:k+3]

# Print the selected sentences
for sentence in selected_sentences:
    print(sentence.text)
# Out:
# To help dogs get the personalized nutrition they need, the brand teamed up with top athlete and health enthusiast Laila Ali to launch EverRoot’s new line of soft chew dog supplements.
# As a fitness expert, Ali believes in extending the same care she takes for her own health to her beloved pups, Malibu and Buddy.
# “I want them to be around for the long haul, so it feels good to know I’m giving my dogs the best chance to look and feel their best with tasty soft chews they love,” said Ali, who is the daughter of the late great professional boxer and humanitarian Muhammad Ali.

# %% [markdown]
# Interpretation: This code snippet randomly selects and prints three consecutive sentences from a given text, demonstrating a way to sample sections of content for analysis or review. It showcases the flexibility in accessing and manipulating text data, providing a glimpse into the document's discussion on dog health and nutrition through the perspective of Laila Ali, highlighting her collaboration with EverRoot on dog supplements.

# %%
#1.2.4 Extract part-of-speech and lemmatize these consecutive sentences

# Extracting part-of-speech and lemmatize for each token in the selected sentences
for sentence in selected_sentences:
    print("\nProcessing sentence:", sentence.text)
    for token in sentence:
        pos_tag = token.pos_
        lemma = token.lemma_
        print(f"Token: {token.text}, POS: {pos_tag}, Lemma: {lemma}")
# Out:
# Processing sentence: To help dogs get the personalized nutrition they need, the brand teamed up with top athlete and health enthusiast Laila Ali to launch EverRoot’s new line of soft chew dog supplements.
# Token: To, POS: PART, Lemma: to
# Token: help, POS: VERB, Lemma: help
# Token: dogs, POS: NOUN, Lemma: dog
# Token: get, POS: VERB, Lemma: get
# Token: the, POS: DET, Lemma: the
# Token: personalized, POS: ADJ, Lemma: personalized
# Token: nutrition, POS: NOUN, Lemma: nutrition
# Token: they, POS: PRON, Lemma: they
# Token: need, POS: VERB, Lemma: need
# Token: ,, POS: PUNCT, Lemma: ,
# Token: the, POS: DET, Lemma: the
# Token: brand, POS: NOUN, Lemma: brand
# Token: teamed, POS: VERB, Lemma: team
# Token: up, POS: ADP, Lemma: up
# Token: with, POS: ADP, Lemma: with
# Token: top, POS: ADJ, Lemma: top
# Token: athlete, POS: NOUN, Lemma: athlete
# Token: and, POS: CCONJ, Lemma: and
# Token: health, POS: NOUN, Lemma: health
# Token: enthusiast, POS: NOUN, Lemma: enthusiast
# Token: Laila, POS: PROPN, Lemma: Laila
# Token: Ali, POS: PROPN, Lemma: Ali
# Token: to, POS: PART, Lemma: to
# Token: launch, POS: VERB, Lemma: launch
# Token: EverRoot, POS: PROPN, Lemma: EverRoot
# Token: ’s, POS: PART, Lemma: ’s
# Token: new, POS: ADJ, Lemma: new
# Token: line, POS: NOUN, Lemma: line
# Token: of, POS: ADP, Lemma: of
# Token: soft, POS: ADJ, Lemma: soft
# Token: chew, POS: NOUN, Lemma: chew
# Token: dog, POS: NOUN, Lemma: dog
# Token: supplements, POS: NOUN, Lemma: supplement
# Token: ., POS: PUNCT, Lemma: .
#
# Processing sentence: As a fitness expert, Ali believes in extending the same care she takes for her own health to her beloved pups, Malibu and Buddy.
# Token: As, POS: ADP, Lemma: as
# Token: a, POS: DET, Lemma: a
# Token: fitness, POS: NOUN, Lemma: fitness
# Token: expert, POS: NOUN, Lemma: expert
# Token: ,, POS: PUNCT, Lemma: ,
# Token: Ali, POS: PROPN, Lemma: Ali
# Token: believes, POS: VERB, Lemma: believe
# Token: in, POS: ADP, Lemma: in
# Token: extending, POS: VERB, Lemma: extend
# Token: the, POS: DET, Lemma: the
# Token: same, POS: ADJ, Lemma: same
# Token: care, POS: NOUN, Lemma: care
# Token: she, POS: PRON, Lemma: she
# Token: takes, POS: VERB, Lemma: take
# Token: for, POS: ADP, Lemma: for
# Token: her, POS: PRON, Lemma: her
# Token: own, POS: ADJ, Lemma: own
# Token: health, POS: NOUN, Lemma: health
# Token: to, POS: ADP, Lemma: to
# Token: her, POS: PRON, Lemma: her
# Token: beloved, POS: ADJ, Lemma: beloved
# Token: pups, POS: NOUN, Lemma: pup
# Token: ,, POS: PUNCT, Lemma: ,
# Token: Malibu, POS: PROPN, Lemma: Malibu
# Token: and, POS: CCONJ, Lemma: and
# Token: Buddy, POS: PROPN, Lemma: Buddy
# Token: ., POS: PUNCT, Lemma: .
#
# Processing sentence: “I want them to be around for the long haul, so it feels good to know I’m giving my dogs the best chance to look and feel their best with tasty soft chews they love,” said Ali, who is the daughter of the late great professional boxer and humanitarian Muhammad Ali.
# Token: “, POS: PUNCT, Lemma: "
# Token: I, POS: PRON, Lemma: I
# Token: want, POS: VERB, Lemma: want
# Token: them, POS: PRON, Lemma: they
# Token: to, POS: PART, Lemma: to
# Token: be, POS: AUX, Lemma: be
# Token: around, POS: ADV, Lemma: around
# Token: for, POS: ADP, Lemma: for
# Token: the, POS: DET, Lemma: the
# Token: long, POS: ADJ, Lemma: long
# Token: haul, POS: NOUN, Lemma: haul
# Token: ,, POS: PUNCT, Lemma: ,
# Token: so, POS: SCONJ, Lemma: so
# Token: it, POS: PRON, Lemma: it
# Token: feels, POS: VERB, Lemma: feel
# Token: good, POS: ADJ, Lemma: good
# Token: to, POS: PART, Lemma: to
# Token: know, POS: VERB, Lemma: know
# Token: I, POS: PRON, Lemma: I
# Token: ’m, POS: AUX, Lemma: ’m
# Token: giving, POS: VERB, Lemma: give
# Token: my, POS: PRON, Lemma: my
# Token: dogs, POS: NOUN, Lemma: dog
# Token: the, POS: DET, Lemma: the
# Token: best, POS: ADJ, Lemma: good
# Token: chance, POS: NOUN, Lemma: chance
# Token: to, POS: PART, Lemma: to
# Token: look, POS: VERB, Lemma: look
# Token: and, POS: CCONJ, Lemma: and
# Token: feel, POS: VERB, Lemma: feel
# Token: their, POS: PRON, Lemma: their
# Token: best, POS: ADJ, Lemma: good
# Token: with, POS: ADP, Lemma: with
# Token: tasty, POS: ADJ, Lemma: tasty
# Token: soft, POS: ADJ, Lemma: soft
# Token: chews, POS: NOUN, Lemma: chew
# Token: they, POS: PRON, Lemma: they
# Token: love, POS: VERB, Lemma: love
# Token: ,, POS: PUNCT, Lemma: ,
# Token: ”, POS: PUNCT, Lemma: "
# Token: said, POS: VERB, Lemma: say
# Token: Ali, POS: PROPN, Lemma: Ali
# Token: ,, POS: PUNCT, Lemma: ,
# Token: who, POS: PRON, Lemma: who
# Token: is, POS: AUX, Lemma: be
# Token: the, POS: DET, Lemma: the
# Token: daughter, POS: NOUN, Lemma: daughter
# Token: of, POS: ADP, Lemma: of
# Token: the, POS: DET, Lemma: the
# Token: late, POS: ADJ, Lemma: late
# Token: great, POS: ADJ, Lemma: great
# Token: professional, POS: ADJ, Lemma: professional
# Token: boxer, POS: NOUN, Lemma: boxer
# Token: and, POS: CCONJ, Lemma: and
# Token: humanitarian, POS: PROPN, Lemma: humanitarian
# Token: Muhammad, POS: PROPN, Lemma: Muhammad
# Token: Ali, POS: PROPN, Lemma: Ali
# Token: ., POS: PUNCT, Lemma: .

# %% [markdown]
# Interpretation: This code uses the SpaCy library to analyze sentences, identifying each word's part of speech and its base form (lemma). It processes three consecutive sentences from a text, highlighting the grammatical role and the root form of each word, which aids in understanding the sentence structure and content at a deeper linguistic level.

# %%
#1.2.5 Get and print the entity annotation for each token of the Kth sentence

kth_sentence = selected_sentences[0]

print("Entity annotation for each token in the Kth sentence:")
for token in kth_sentence:
    entity = token.ent_type_ if token.ent_type_ else 'No Entity'
    print(f"Token: {token.text}, Entity: {entity}")
# Out:
# Entity annotation for each token in the Kth sentence:
# Token: To, Entity: No Entity
# Token: help, Entity: No Entity
# Token: dogs, Entity: No Entity
# Token: get, Entity: No Entity
# Token: the, Entity: No Entity
# Token: personalized, Entity: No Entity
# Token: nutrition, Entity: No Entity
# Token: they, Entity: No Entity
# Token: need, Entity: No Entity
# Token: ,, Entity: No Entity
# Token: the, Entity: No Entity
# Token: brand, Entity: No Entity
# Token: teamed, Entity: No Entity
# Token: up, Entity: No Entity
# Token: with, Entity: No Entity
# Token: top, Entity: No Entity
# Token: athlete, Entity: No Entity
# Token: and, Entity: No Entity
# Token: health, Entity: No Entity
# Token: enthusiast, Entity: No Entity
# Token: Laila, Entity: PERSON
# Token: Ali, Entity: PERSON
# Token: to, Entity: No Entity
# Token: launch, Entity: No Entity
# Token: EverRoot, Entity: PRODUCT
# Token: ’s, Entity: No Entity
# Token: new, Entity: No Entity
# Token: line, Entity: No Entity
# Token: of, Entity: No Entity
# Token: soft, Entity: No Entity
# Token: chew, Entity: No Entity
# Token: dog, Entity: No Entity
# Token: supplements, Entity: No Entity
# Token: ., Entity: No Entity

# %% [markdown]
# Interpretation: This code snippet extracts and prints the entity type (such as PERSON, ORGANIZATION, etc.) for each word in a selected sentence, using SpaCy's named entity recognition capabilities. It identifies the entities within the first sentence of a predefined list, assigning "No Entity" to tokens that do not belong to a specific entity category. For instance, "Laila" and "Ali" are recognized as part of a PERSON entity, while "EverRoot" is identified as a PRODUCT.

# %%
#1.2.6 Visualize the entities and dependencies of Kth sentence

from spacy import displacy

# Visualizing the entities in the Kth sentence
displacy.render(kth_sentence, style='ent', jupyter=True)

# Visualizing the dependency parse of the Kth sentence
displacy.render(kth_sentence, style='dep', jupyter=True, options={'distance': 100})
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">To help dogs get the personalized nutrition they need, the brand teamed up with top athlete and health enthusiast
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Laila Ali
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  to launch
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EverRoot
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# ’s new line of soft chew dog supplements. </div></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b9bac5af8ae84eb89b26e6018123dc6f-0" class="displacy" width="3250" height="337.0" direction="ltr" style="max-width: none; height: 337.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">To</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">help</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">dogs</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">get</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">personalized</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">nutrition</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">they</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">need,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">brand</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">teamed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">up</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1350">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1350">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">top</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">athlete</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1750">health</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">enthusiast</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1950">Laila</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2050">Ali</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2050">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2250">launch</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2350">EverRoot</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2350">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">’s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2550">new</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2550">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2650">line</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">soft</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2950">chew</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">dog</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NO

# %% [markdown]
# Interpretation: The code uses SpaCy's displacy module to visually display named entities and the grammatical structure of a sentence. It highlights entities like "Laila Ali" as a PERSON and "EverRoot" as a PRODUCT and shows the grammatical connections between words in the sentence, illustrating their roles and relationships.

# %%
#1.2.7 Visualize all the entities in the document

from spacy import displacy

displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Every dog deserves to feel their best, but like humans, they all have unique needs. Regular vet visits, proper diet and exercise can all help, but sometimes our canine pals need a little extra support above and beyond their normal diet. That’s where EverRoot dog supplements, powered by
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Purina
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  come in: Developed by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Purina
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s experts in animal nutrition,
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EverRoot
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  dog supplements come in multiple forms, covering a variety of key health benefit areas. This helps pet parents further personalize their dog’s supplement plan to meet their unique needs and preferences. With a focus on natural and organic ingredients and a commitment to traceable sourcing, EverRoot stands out for making sure that their dog supplements have everything your dog needs, without the things they don’t. To help dogs get the personalized nutrition they need, the brand teamed up with top athlete and health enthusiast
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Laila Ali
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  to launch
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EverRoot
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# ’s new line of soft chew dog supplements. As a fitness expert,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ali
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  believes in extending the same care she takes for her own health to her beloved pups,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Malibu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Buddy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . “I want them to be around for the long haul, so it feels good to know I’m giving my dogs the best chance to look and feel their best with tasty soft chews they love,” said
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ali
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , who is the daughter of the late great professional boxer and humanitarian
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Muhammad Ali
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . To her credit,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ali
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is a
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     four
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# -time undefeated boxing world champion, CEO of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Laila Ali Lifestyle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  brand and a devoted dog enthusiast. Inspired by her love for animals, she collaborated with EverRoot to introduce EverRoot
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Soft Chews
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . At home, these chews provide a way for
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ali
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  to take care of her own dogs based on their unique needs and preferences; she gives
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Buddy the EverRoot
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  soft chew supplement for hip and joint support and the
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EverRoot
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  multi-benefit soft chew to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Malibu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . However, pet owners don’t need to be sports heroes like
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ali
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  to provide world-class care to their pets. Thanks to
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EverRoot
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# , meeting a dog’s uniq

# %% [markdown]
# Interpretation: The code uses spaCy and its visualization tool displacy to display the named entities present in a processed text document within a Jupyter notebook, showing entities like people, organizations, and products for quick analysis.

# %%
#2 De-Identification:
2.1 De-identify all person names (PERSON) in the webpage document with [REDACTED] and visualize them.

redacted_text = article_text
sentences= list(doc.sents)
for i in sentences:
    for j in i:
        if j.ent_type_ == 'PERSON':
            redacted_text = redacted_text.replace(str(j), '[REDACTED]')

print(redacted_text)
# Out:
# Every dog deserves to feel their best, but like humans, they all have unique needs. Regular vet visits, proper diet and exercise can all help, but sometimes our canine pals need a little extra support above and beyond their normal diet. That’s where EverRoot dog supplements, powered by Purina come in: Developed by Purina’s experts in animal nutrition, EverRoot dog supplements come in multiple forms, covering a variety of key health benefit areas. This helps pet parents further personalize their dog’s supplement plan to meet their unique needs and preferences. With a focus on natural and organic ingredients and a commitment to traceable sourcing, EverRoot stands out for making sure that their dog supplements have everything your dog needs, without the things they don’t. To help dogs get the personalized nutrition they need, the brand teamed up with top athlete and health enthusiast [REDACTED] [REDACTED] to launch EverRoot’s new line of soft chew dog supplements. As a fitness expert, [REDACTED] believes in extending the same care she takes for her own health to her beloved pups, Malibu and Buddy. “I want them to be around for the long haul, so it feels good to know I’m giving my dogs the best chance to look and feel their best with tasty soft chews they love,” said [REDACTED], who is the daughter of the late great professional boxer and humanitarian [REDACTED] [REDACTED]. To her credit, [REDACTED] is a four-time undefeated boxing world champion, CEO of [REDACTED] [REDACTED] [REDACTED] brand and a devoted dog enthusiast. Inspired by her love for animals, she collaborated with EverRoot to introduce EverRoot [REDACTED] [REDACTED]. At home, these chews provide a way for [REDACTED] to take care of her own dogs based on their unique needs and preferences; she gives Buddy the EverRoot soft chew supplement for hip and joint support and the EverRoot multi-benefit soft chew to Malibu. However, pet owners don’t need to be sports heroes like [REDACTED] to provide world-class care to their pets. Thanks to EverRoot, meeting a dog’s unique wellness needs just got a whole lot easier. Finding the right ingredients is key With more than a century of experience, Purina and its scientists are trusted experts in animal nutrition. They understand that all dogs are different, and that’s why EverRoot [REDACTED] [REDACTED] are formulated to benefit their needs. EverRoot takes pride in helping dogs on their personal health journeys. To do just that, the brand has committed to sourcing and traceability practices. Every ingredient in EverRoot dog supplements has a purpose, a reason to be there. In creating supplements, they have searched the world for organic ingredients, such as soothing chamomile and [REDACTED] [REDACTED] coconut, and sourced oils from wild-caught Alaskan salmon and cod from Marine Stewardship Council-certified fisheries. Using high-quality ingredients produces equally strong benefits. As one example, the chamomile EverRoot uses in their supplement can help calm nervous pups. Likewise, organic coconut and fish support a dog’s overall well-being, from joint, skin and coat health to mental alertness. They’ve also tapped into unexpected ingredients like green-lipped mussels harvested from New Zealand’s pristine waters to support heart health. Since ancient times, safflower oil has been a valued skin remedy and remains effective in supporting sensitive skin today. EverRoot has also sourced Montmorency cherries for their organic tart cherry powder to promote cognitive function and mental alertness. These are just a few examples of the carefully selected ingredients that ensure dogs get the best nutrition in a form that they’ll love. Health benefits and a taste dogs enjoy EverRoot’s dog supplements cover a wide range of health benefits and natural ingredients tailored for dogs including: Dr. [REDACTED] [REDACTED], who has a doctorate in animal behavior and works as a principal scientist in pet behavior and welfare at Purina, stresses the impor ...

# %%
displacy.render(nlp(redacted_text),jupyter= True,style= 'ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Every dog deserves to feel their best, but like humans, they all have unique needs. Regular vet visits, proper diet and exercise can all help, but sometimes our canine pals need a little extra support above and beyond their normal diet. That’s where EverRoot dog supplements, powered by
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Purina
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  come in: Developed by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Purina
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s experts in animal nutrition,
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EverRoot
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  dog supplements come in multiple forms, covering a variety of key health benefit areas. This helps pet parents further personalize their dog’s supplement plan to meet their unique needs and preferences. With a focus on natural and organic ingredients and a commitment to traceable sourcing, EverRoot stands out for making sure that their dog supplements have everything your dog needs, without the things they don’t. To help dogs get the personalized nutrition they need, the brand teamed up with top athlete and health enthusiast [REDACTED] [REDACTED] to launch
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EverRoot
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# ’s new line of soft chew dog supplements. As a fitness expert, [REDACTED] believes in extending the same care she takes for her own health to her beloved pups,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Malibu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Buddy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . “I want them to be around for the long haul, so it feels good to know I’m giving my dogs the best chance to look and feel their best with tasty soft chews they love,” said [REDACTED], who is the daughter of the late great professional boxer and humanitarian [REDACTED] [REDACTED]. To her credit, [REDACTED] is a
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     four
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# -time undefeated boxing world champion, CEO of [REDACTED] [REDACTED] [REDACTED] brand and a devoted dog enthusiast. Inspired by her love for animals, she collaborated with EverRoot to introduce EverRoot [REDACTED] [REDACTED]. At home, these chews provide a way for [REDACTED] to take care of her own dogs based on their unique needs and preferences; she gives
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Buddy the EverRoot
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  soft chew supplement for hip and joint support and the
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EverRoot
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  multi-benefit soft chew to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Malibu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . However, pet owners don’t need to be sports heroes like [REDACTED] to provide world-class care to their pets. Thanks to
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EverRoot
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# , meeting a dog’s unique wellness needs just got a whole lot easier. Finding the right ingredients is key With
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than a century
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  of experience,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Purina
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and its scientists are trusted experts in animal nutrition. They understand that all dogs are different, and that’s why EverRoot [REDACTED] [REDACTED] are formulated to benefit their needs. EverRoot takes pride in helping dogs on their personal health journeys. To do just that, the brand has committed to sourcing and traceability practices. Every ingredient in
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EverRoot
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  dog supplements has a purpose, a reason to be there. In creating supplements, they have searched the world for organic ingredients, such as soothing chamomile and [REDACTED] [REDACTED] coconut, and sourced oils from wild-caught
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alaskan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  salmon and cod from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Marine Stewardship Council
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# -certified fisheries. Using high-quality ingredients produces equally strong benefits. As
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-

# %% [markdown]
# Interpretation: The 'De-Identification' section instructs to replace all named entities classified as "PERSON" with [REDACTED]. This involves using a natural language processing library such as SpaCy to identify and classify named entities, and then replace any entities classified as persons with the redaction label.
